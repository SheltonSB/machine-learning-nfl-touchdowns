# %%
# EDA Notebook for NFL QB TD Predictor 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set styling
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# Load Data
game_logs = pd.read_csv('../data/raw/Game_Logs_Quarterback.csv')
career_stats = pd.read_csv('../data/raw/Career_Stats_Passing.csv')
basic_stats = pd.read_csv('../data/raw/Basic_Stats.csv')

# Preview
print("Game Logs Shape:", game_logs.shape)
print("Career Stats Shape:", career_stats.shape)
print("Basic Stats Shape:", basic_stats.shape)

display(game_logs.head())
display(career_stats.head())
display(basic_stats.head())
# Out:
# Game Logs Shape: (40247, 29)
# Career Stats Shape: (8525, 23)
# Basic Stats Shape: (17172, 16)
#                 Player Id              Name Position  Year          Season  \
# 0  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 1  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 2  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 3  jaredzabransky/2495791  Zabransky, Jared      NaN  2007       Preseason
# 4      billdemory/2512778      Demory, Bill      NaN  1974  Regular Season
#
#    Week Game Date Home or Away Opponent Outcome  ... Ints  Sacks  \
# 0     1     08/11         Home      CHI       L  ...   --     --
# 1     2     08/18         Away      ARI       W  ...    0      0
# 2     3     08/25         Home      DAL       W  ...   --     --
# 3     4     08/30         Away       TB       L  ...    1      2
# 4     1     09/15         Away       KC       L  ...   --     --
#
# ...

# %%
# Check for nulls
print("Game Logs Nulls:")
print(game_logs.isnull().sum())
print("\nCareer Stats Nulls:")
print(career_stats.isnull().sum())
print("\nBasic Stats Nulls:")
print(basic_stats.isnull().sum())

# Unique QBs and Opponents
print("\nUnique QBs in game logs:", game_logs['Name'].nunique())
print("Unique Opponents:", game_logs['Opponent'].nunique())
# Out:
# Game Logs Nulls:
# Player Id                        0
# Name                             0
# Position                     30153
# Year                             0
# Season                           0
# Week                             0
# Game Date                        0
# Home or Away                     0
# Opponent                         0
# Outcome                          0
# Score                            0
# Games Played                     0
# Games Started                    0
# Passes Completed                 0
# Passes Attempted                 0
# Completion Percentage            0
# Passing Yards                    0
# Passing Yards Per Attempt        0
# TD Passes                        0
# Ints                             0
# Sacks                            0
# Sacked Yards Lost                0
# Passer Rating                    0
# Rushing Attempts                 0
# Rushing Yards                    0
# Yards Per Carry                  0
# ...
